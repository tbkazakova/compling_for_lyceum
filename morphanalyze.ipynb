# %% [markdown]
# # Условия и операторы сравнения

# %% [markdown]
# ```
# if условие:
#     блок инструкций, в случае если условие истинно
# else:
#     блок инструкций, в случае если условие не выполняется
# ```

# %%
number = -6
if number < 0:
    print("отрицательное число")
else:
    print("положительное число")  # лучше "неотрицательное"
# Out:
# отрицательное число

# %%
# но ноль - ни положительное, ни отрицательное

number = 0
if number < 0:
    print("отрицательное число")
else:
    if number == 0:
        print("ноль")
    else:
        print("положительное число")
# Out:
# ноль

# %% [markdown]
# Но условия в условии можно красиво избежать:

# %%
if number > 0:
    print("положительное число")
elif number == 0:  # таких elif может быть много, после них пишут альтернативные условия
    print("ноль")
else:
    print("отрицательное число")
# Out:
# ноль

# %% [markdown]
# ### Основные операторы сравнения
#
# - \> - больше. Условие истинно, если то, что слева от знака больше того, что справа
# - < - меньше. Условие истинно, если то, что слева от знака меньше того, что справа
# - \>= - больше либо равно
# - <= - меньше либо равно
# - == - в точности равно
# - != - не равно

# %% [markdown]
# ### Тренировка
# Пользователь вводит число и получает это число в кубе (возвести в степень: 5\*\*3 = 5\*5\*5 = 125)
#
# Пользователь может отказаться словом "стоп" (программа выводит сообщение: "вы отказались от услуги")

# %%
# ваш код

# %% [markdown]
# ### Тип данных bool
#
# Всего два значения: True и False С большой буквы.
#
# (Не называйте переменные true или false - мы за красивый понятный код)

# %%
print(5>0)
print(type(5>0))
print(5==0)
# Out:
# True
# <class 'bool'>
# False

# %%
# bool переводится в число
print(int(True))
print(int(False))
# Out:
# 1
# 0

# %%
# Числа переводятся в bool: все кроме нуля - True
print(bool(4))
print(bool(-6.578))
print(bool(0))
# Out:
# True
# True
# False

# %%
# Строки переводятся в bool: все кроме '' - True
print(bool('непустая строка'))
print(bool(''))
# Out:
# True
# False

# %%
# Поэтому можно так:
name = input("Введите имя: ")
if name:
    print("Привет, ", name)
else:
    print("Вы не ввели имя...")
# Out:
# Введите имя: Антон
# Привет,  Антон

# %% [markdown]
# ### Логические операторы
# - **and** (логическое И) возвращает истину (True), если оба условия по отдельности верны (тоже возвращают True)
# - **or** (логическое ИЛИ) вернет истину, если хотя бы одно из условий верно
# - **not** (логическое НЕТ) возьмет результат условия и “обратит” его.

# %%
a = int(input())
b = int(input())

if a % 10 == 0 or b % 10 == 0:
    print('Хотя бы одно число кратно 10.')
else:
    print('Оба числа не кратны 10.')
# Out:
# 5
# 10
# Хотя бы одно число кратно 10.

# %% [markdown]
# # Циклы
#
# ###for

# %%
for letter in 'hello':
    print(letter)
# Out:
# h
# e
# l
# l
# o

# %%
words = ['сочиняю', 'я', 'неплохо', "иногда", "да"]
for word in words:
  print(word)
# Out:
# сочиняю
# я
# неплохо
# иногда
# да

# %% [markdown]
# ### range()
#
# перебирает целые числа

# %%
for number in range(5):  # числа от нуля до 5 не включительно
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# range(x, y) - числа от x до y-1
for number in range(4, 7):
    print(number)
# Out:
# 4
# 5
# 6

# %%
# range(x, y, step) выдаёт все целые числа начиная с x с шагом step, но не включая y
for number in range(5, -1, -1):
    print(number)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# Вспомнили. Теперь про языковое

# %% [markdown]
# # [pymorphy2](https://pymorphy2.readthedocs.io/en/stable/index.html) - морфологический анализатор для русского
#
# При работе используется словарь OpenCorpora; для незнакомых слов строятся гипотезы.

# %%
! pip install pymorphy3  # устанавливаем
# Out:
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (75.2.0)
# Downloading pymorphy3-2.0.6-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 1.4 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142

# %%
from pymorphy3 import MorphAnalyzer
morph = MorphAnalyzer()

# %%
morph.parse('маме')
# Out:
# [Parse(word='маме', tag=OpencorporaTag('NOUN,anim,femn sing,datv'), normal_form='мама', score=0.933333, methods_stack=((DictionaryAnalyzer(), 'маме', 1987, 2),)),
#  Parse(word='маме', tag=OpencorporaTag('NOUN,anim,femn sing,loct'), normal_form='мама', score=0.066666, methods_stack=((DictionaryAnalyzer(), 'маме', 1987, 6),))]

# %%
morph.parse('абракадабры') # умеет давать грам.информацию, лемму
# Out:
# [Parse(word='абракадабры', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='абракадабра', score=0.3333333333333333, methods_stack=((DictionaryAnalyzer(), 'абракадабры', 55, 1),)),
#  Parse(word='абракадабры', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='абракадабра', score=0.3333333333333333, methods_stack=((DictionaryAnalyzer(), 'абракадабры', 55, 7),)),
#  Parse(word='абракадабры', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='абракадабра', score=0.3333333333333333, methods_stack=((DictionaryAnalyzer(), 'абракадабры', 55, 10),))]

# %%
morph.parse('ПиЛа')  # регистр не влияет
# Out:
# [Parse(word='пила', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='пила', score=0.428571, methods_stack=((DictionaryAnalyzer(), 'пила', 55, 0),)),
#  Parse(word='пила', tag=OpencorporaTag('VERB,impf,tran femn,sing,past,indc'), normal_form='пить', score=0.285714, methods_stack=((DictionaryAnalyzer(), 'пила', 465, 8),)),
#  Parse(word='пила', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='пил', score=0.142857, methods_stack=((DictionaryAnalyzer(), 'пила', 27, 1),)),
#  Parse(word='пила', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='пил', score=0.142857, methods_stack=((DictionaryAnalyzer(), 'пила', 27, 3),))]

# %%
morph.parse('водомотодельтаплан')  # для незнакомых слов делает предположения по похожим
# Out:
# [Parse(word='водомотодельтаплан', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='водомотодельтаплан', score=0.5, methods_stack=((DictionaryAnalyzer(), 'мотодельтаплан', 34, 0), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'водо'))),
#  Parse(word='водомотодельтаплан', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='водомотодельтаплан', score=0.5, methods_stack=((DictionaryAnalyzer(), 'мотодельтаплан', 34, 3), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'водо')))]

# %%
morph.parse('вулканоизвержение')
# Out:
# [Parse(word='вулканоизвержение', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='вулканоизвержение', score=0.5, methods_stack=((FakeDictionary(), 'вулканоизвержение', 77, 0), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'жение'))),
#  Parse(word='вулканоизвержение', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='вулканоизвержение', score=0.5, methods_stack=((FakeDictionary(), 'вулканоизвержение', 77, 6), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'жение')))]

# %%
morph.parse('глокая')
# Out:
# [Parse(word='глокая', tag=OpencorporaTag('GRND,impf,intr pres'), normal_form='глокать', score=0.2795031055900621, methods_stack=((DictionaryAnalyzer(), 'окая', 15, 67), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гл'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='глокай', score=0.2795031055900621, methods_stack=((DictionaryAnalyzer(), 'кая', 42, 1), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гло'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='глокай', score=0.2795031055900621, methods_stack=((DictionaryAnalyzer(), 'кая', 42, 3), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гло'))),
#  Parse(word='глокая', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='глокий', score=0.14906832298136644, methods_stack=((FakeDictionary(), 'глокая', 395, 7), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,inan,masc,Sgtm,Geox sing,gent'), normal_form='глокай', score=0.006211180124223602, methods_stack=((FakeDictionary(), 'глокая', 43, 1), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='глокай', score=0.006211180124223602, methods_stack=((FakeDictionary(), 'глокая', 1217, 1), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая')))]

# %%
door = morph.parse('дверь')[0]  # может ставить слова в любую форму
print(door)
print(door.inflect({'plur','ablt'}))
# Out:
# Parse(word='дверь', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='дверь', score=0.612903, methods_stack=((DictionaryAnalyzer(), 'дверь', 1310, 3),))
# Parse(word='дверями', tag=OpencorporaTag('NOUN,inan,femn plur,ablt'), normal_form='дверь', score=1.0, methods_stack=((DictionaryAnalyzer(), 'дверями', 1310, 12),))

# %%
glokaja = morph.parse('глокая')
glokaja
# Out:
# [Parse(word='глокая', tag=OpencorporaTag('GRND,impf,intr pres'), normal_form='глокать', score=0.27950310559006214, methods_stack=((DictionaryAnalyzer(), 'окая', 15, 67), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гл'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='глокай', score=0.27950310559006214, methods_stack=((DictionaryAnalyzer(), 'кая', 42, 1), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гло'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='глокай', score=0.27950310559006214, methods_stack=((DictionaryAnalyzer(), 'кая', 42, 3), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гло'))),
#  Parse(word='глокая', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='глокий', score=0.14906832298136646, methods_stack=((FakeDictionary(), 'глокая', 395, 7), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,inan,masc,Sgtm,Geox sing,gent'), normal_form='глокай', score=0.006211180124223603, methods_stack=((FakeDictionary(), 'глокая', 43, 1), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая'))),
#  Parse(word='глокая', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='глокай', score=0.006211180124223603, methods_stack=((FakeDictionary(), 'глокая', 1217, 1), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'окая')))]

# %%
print(glokaja[0].inflect({'past'})) # подберёт морфологию для несуществующих слов
# Out:
# Parse(word='глокав', tag=OpencorporaTag('GRND,impf,intr past'), normal_form='глокать', score=1.0, methods_stack=((DictionaryAnalyzer(), 'окав', 15, 68), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'гл')))

# %% [markdown]
# ### [Mystem](https://pypi.org/project/pymystem3/)
#
# Анализатор для русского от Yandex

# %%
! pip install pymystem3
# Out:
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pymystem3) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (2025.11.12)
# Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0

# %%
from pymystem3 import Mystem

# %%
text = "Я увидела белок"
m = Mystem()
m.lemmatize(text)
# Out:
# Installing mystem to /root/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-linux-64bit.tar.gz
# ['я', ' ', 'увидеть', ' ', 'белок', '\n']

# %%
m.analyze(text)
# Out:
# [{'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'Я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'увидеть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,жен'}],
#   'text': 'увидела'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'белок',
#     'wt': 0.9303359821,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'белок'},
#  {'text': '\n'}]

# %%
text = "Папа помыл стекло"
m.analyze(text)
# Out:
# [{'analysis': [{'lex': 'папа', 'wt': 0.9996149827, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Папа'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'помыть', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'помыл'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стекло',
#     'wt': 0.9853860572,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'стекло'},
#  {'text': '\n'}]

# %%
text = "Тот заяц белый"
m.analyze(text)
# Out:
# [{'analysis': [{'lex': 'тот',
#     'wt': 1,
#     'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'Тот'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заяц', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'заяц'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'белый',
#     'wt': 0.9725893425,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'белый'},
#  {'text': '\n'}]

# %%
text = "сабака"
m.analyze(text)
# Out:
# [{'analysis': [{'lex': 'сабак',
#     'wt': 0.1654796749,
#     'qual': 'bastard',
#     'gr': 'S,муж,неод=род,ед'}],
#   'text': 'сабака'},
#  {'text': '\n'}]

# %%
text = "Тот заяц как-то высоко прыгал. Себя увидел. Сколько зим...."
m.analyze(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2843510134.py in <cell line: 0>()
#       1 text = "Тот заяц как-то высоко прыгал. Себя увидел. Сколько зим...."
# ----> 2 m.analyze(text)
#
# NameError: name 'm' is not defined

# %%
a = m.analyze(text)
a[6]['analysis'][0]['gr']
# Out:
# 'V,несов,нп=прош,ед,изъяв,муж'

# %% [markdown]
# # [NLTK](https://www.nltk.org/)

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_rus')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_rus.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_ru')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
# True

# %%
from nltk import pos_tag, word_tokenize

# %%
word_tokenize('Мила! Мама мыла.')
# Out:
# ['Мила', '!', 'Мама', 'мыла', '.']

# %%
pos_tag(word_tokenize('Мила! Холодно. Я мыла раму красивую, задумавшись.'), lang='rus')
# Out:
# [('Мила', 'S'),
#  ('!', 'NONLEX'),
#  ('Холодно', 'ADV'),
#  ('.', 'NONLEX'),
#  ('Я', 'S-PRO'),
#  ('мыла', 'V'),
#  ('раму', 'S'),
#  ('красивую', 'A=f'),
#  (',', 'NONLEX'),
#  ('задумавшись', 'V'),
#  ('.', 'NONLEX')]

# %% [markdown]
# # [Spacy](https://spacy.io/usage/linguistic-features)
#
# Большой проект, натренированные модели для 25 языков

# %%
import spacy

# %%
! python3 -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.8.0/ru_core_news_sm-3.8.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 46.9 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0 (from ru-core-news-sm==3.8.0)
#   Downloading pymorphy3-2.0.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0) (75.2.0)
# Downloading pymorphy3-2.0.6-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 1.8 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 62.4 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("ru_core_news_sm")

# %%
text = "Тот заяц как-то высоко прыгал. Себя увидел. Сколько зим...."

doc = nlp(text)
print(doc.text)
# Out:
# Тот заяц как-то высоко прыгал. Себя увидел. Сколько зим....

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Тот заяц как-то высоко прыгал.
# Себя увидел.
# Сколько зим....

# %%
for element in doc:
    print(element.text, element.lemma_)
# Out:
# Тот тот
# заяц заяц
# как как
# - -
# то то
# высоко высоко
# прыгал прыгать
# . .
# Себя себя
# увидел увидеть
# . .
# Сколько сколько
# зим зим
# .... ....

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.morph)
# Out:
# Тот тот DET Case=Nom|Gender=Masc|Number=Sing
# заяц заяц NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# как как ADV Degree=Pos
# - - ADV Degree=Pos
# то то ADV Degree=Pos
# высоко высоко ADV Degree=Pos
# прыгал прыгать VERB Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# . . PUNCT
# Себя себя PRON Case=Acc
# увидел увидеть VERB Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# . . PUNCT
# Сколько сколько NUM Animacy=Inan|Case=Acc
# зим зим NOUN Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
# .... .... PUNCT

# %% [markdown]
# # [Stanza](https://stanfordnlp.github.io/stanza/index.html)
#
# Большой проект, натренированные модели для 70 языков.
#
# Материал, на котором тренировались модели: [Universal Dependencies](https://universaldependencies.org/)

# %%
! pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.11.0-py3-none-any.whl.metadata (14 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (5.29.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza) (3.6)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Downloading stanza-1.11.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.8 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 34.9 MB/s eta 0:00:00
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.15.0 stanza-1.11.0

# %%
import stanza

# %%
stanza.download("ru")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: ru (Russian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.11.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/ru/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources

# %%
nlp = stanza.Pipeline(lang="ru", processors="tokenize, pos, lemma, depparse, ner")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# | ner       | wikiner            |
# ==================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
doc = nlp('Мила! Мама мыла.')

# %%
doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Мила",
#       "lemma": "мила",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "B-MISC",
#       "multi_ner": [
#         "B-MISC"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 2,
#       "text": "!",
#       "lemma": "!",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "punct",
#       "start_char": 4,
#       "end_char": 5,
#       "ner": "E-MISC",
#       "multi_ner": [
#         "E-MISC"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Мама",
#       "lemma": "мама",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "nsubj",
#       "start_char": 6,
#       "end_char": 10,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "мыла",
#       "lemma": "мыть",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 11,
#       "end_char": 15,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 3,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 2,
#       "deprel": "punct",
#       "start_char": 15,
#       "end_char": 16,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     }
#   ]
# ]

# %%
doc.sentences
# Out:
# [[
#    {
#      "id": 1,
#      "text": "Мила",
#      "lemma": "мил",
#      "upos": "NOUN",
#      "feats": "Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 0,
#      "end_char": 4,
#      "ner": "B-MISC",
#      "multi_ner": [
#        "B-MISC"
#      ]
#    },
#    {
#      "id": 2,
#      "text": "!",
#      "lemma": "!",
#      "upos": "PUNCT",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 4,
#      "end_char": 5,
#      "ner": "E-MISC",
#      "multi_ner": [
#        "E-MISC"
#      ]
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "Мама",
#      "lemma": "мама",
#      "upos": "NOUN",
#      "feats": "Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing",
#      "head": 2,
#      "deprel": "nsubj",
#      "start_char": 6,
#      "end_char": 10,
#      "ner": "O",
#      "multi_ner": [
#        "O"
#      ]
#    },
#    {
#      "id": 2,
#      "text": "мыла",
#      "lemma": "мыть",
#      "upos": "VERB",
#      "feats": "Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 11,
#      "end_char": 15,
#      "ner": "O",
#      "multi_ner": [
#        "O"
#      ]
#    },
#    {
#      "id": 3,
#      "text": ".",
#      "lemma": ".",
#      "upos": "PUNCT",
#      "head": 2,
#      "deprel": "punct",
#      "start_char": 15,
#      "end_char": 16,
#      "ner": "O",
#      "multi_ner": [
#        "O"
#      ]
#    }
#  ]]

# %%
[word.lemma for sent in doc.sentences for word in sent.words]
# Out:
# ['мил', '!', 'мама', 'мыть', '.']

# %%
print(*[f'word: {word.text}\tupos: {word.upos}\txpos: {word.xpos}\tfeats: {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# word: Мила	upos: NOUN	xpos: None	feats: Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing
# word: !	upos: PUNCT	xpos: None	feats: _
# word: Мама	upos: NOUN	xpos: None	feats: Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing
# word: мыла	upos: VERB	xpos: None	feats: Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# word: .	upos: PUNCT	xpos: None	feats: _

# %% [markdown]
# И много разных для конкретных языков.

# %% [markdown]
# Понимаете, как использовать nltk, spaCy и Stanza для других языков?

# %% [markdown]
# # Соединим наши знания
# Тренируемся:
# - делим текст на слова (если необходимо)
# - печатаем слово и морфологический анализ от разных анализаторов (да, есть сложности с этим)

# %% [markdown]
# А на каком тексте лучше проверять?
#
# Нужен текст, учитывающий сложности и спорные случаи например, омонимию. Попробуйте придумать.
#
#  (ниже не он)

# %%
text = "Жили-были трое троллей на вершинах дальних гор. Жили тролли не скучали, хоть молчали с давних пор. Как-то раз, никто не знает, от каких таких причин..."
